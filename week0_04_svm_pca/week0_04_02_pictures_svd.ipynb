# %% [markdown]
# # Pictures compression using SVD
# In this exercise you are supposed to study how SVD could be used in image compression.
#
# _Based on open course in [Numerical Linear Algebra](https://github.com/oseledets/nla2018) by Ivan Oseledets_

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np


# %matplotlib inline

# %%
# If you are using colab, uncomment this cell

# ! wget https://raw.githubusercontent.com/girafe-ai/ml-mipt/basic/week04_svm_pca/data/waiting.jpeg
# ! wget https://raw.githubusercontent.com/girafe-ai/ml-mipt/basic/week04_svm_pca/data/mipt.jpg
# ! wget https://raw.githubusercontent.com/girafe-ai/ml-mipt/basic/week04_svm_pca/data/simpsons.jpg

# ! mkdir data
# ! mv -t data waiting.jpeg mipt.jpg simpsons.jpg

# %% [markdown]
# ## Singular values
#
# Compute the singular values of some predownloaded image and plot them.
#
# Do not forget to use logarithmic scale.

# %%
face = cv2.imread("data/waiting.jpeg")
face = cv2.cvtColor(face, cv2.COLOR_BGR2RGB)

plt.imshow(face)
plt.xticks(())
plt.yticks(())
plt.title("Original Picture")
plt.show()

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Compress
#
# Complete a function `compress`, that performs SVD and truncates it (using $k$ singular values/vectors). See the prototype below.
#
# Note, that in colourful case you have to split your image to channels and work with matrices corresponding to different channels separately.
#
# Plot approximate reconstructed image $M_\varepsilon$ of your favorite image such that $rank(M_\varepsilon) = 5, 20, 50$ using ```plt.subplots```.

# %%
def compress(image: np.ndarray, k: int) -> (np.ndarray, np.ndarray):
    """Perform svd decomposition and truncate it (using k singular values/vectors)

    Args:
        image: input image (probably, colourful)
        k: approximation rank

    Returns:
      reconst_matrix: reconstructed matrix (tensor in colourful case)
      s: array of singular values
    """
    reconst_matrix = None
    s = None
    # YOUR CODE HERE
    return reconst_matrix, s

# %% [markdown]
# ## Discover
#
# Plot the following two figures for your favorite picture:
#
# * How relative error of approximation depends on the rank of approximation?
# * How compression rate in terms of storing information ((singular vectors + singular numbers) / total size of image) depends on the rank of approximation?

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Compare
#
# Consider the following two pictures. Compute their approximations (with the same rank, or relative error).
#
# What do you see? Explain results.

# %%
one = cv2.imread("data/mipt.jpg")
one = cv2.cvtColor(one, cv2.COLOR_BGR2RGB)

another = cv2.imread("data/simpsons.jpg")
another = cv2.cvtColor(another, cv2.COLOR_BGR2RGB)

plt.figure(figsize=(18, 6))
plt.subplot(1, 2, 1)
plt.imshow(one)
plt.title("One Picture")
plt.xticks(())
plt.yticks(())

plt.subplot(1, 2, 2)
plt.imshow(another)
plt.title("Another Picture")
plt.xticks(())
plt.yticks(())

plt.show()

# %%
# YOUR CODE HERE
